# %%
import os
os.chdir("../")
# %pwd
# Out:
# 'c:\\Users\\Lenovo\\Project\\BTP'

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# c:\Users\Lenovo\Project\BTP
# ['.git', '.gitignore', '.python-version', '.venv', 'data', 'features', 'main.py', 'notebook', 'pipeline', 'pyproject.toml', 'README.md', 'requirements.txt', 'uv.lock']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/dns_data.csv', header=0, names=["label", "family", "domain"])
df.head()
# Out:
#    label   family                            domain
# 0    dga  corebot  cvyh1po636avyrsxebwbkn7.ddns.net
# 1  legit    alexa                plasticbags.sa.com
# 2  legit    alexa                      mzltrack.com
# 3  legit    alexa                      miss-slim.ru
# 4    dga  ranbyus                 txumyqrubwutbb.cc

# %%
df.isnull().sum()
# Out:
# label     0
# family    0
# domain    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(61)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
vc = df.value_counts(df['label'])

# %%
vc
# Out:
# label
# dga      337499
# legit    337337
# Name: count, dtype: int64

# %%
sns.barplot(vc)
# Out:
# <Axes: xlabel='label', ylabel='count'>
